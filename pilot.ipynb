# %%
from nltk.corpus import nps_chat

# %%
len(nps_chat.posts())
# Out:
# 10567

# %%
nps_chat.fileids()
# Out:
# ['10-19-20s_706posts.xml',
#  '10-19-30s_705posts.xml',
#  '10-19-40s_686posts.xml',
#  '10-19-adults_706posts.xml',
#  '10-24-40s_706posts.xml',
#  '10-26-teens_706posts.xml',
#  '11-06-adults_706posts.xml',
#  '11-08-20s_705posts.xml',
#  '11-08-40s_706posts.xml',
#  '11-08-adults_705posts.xml',
#  '11-08-teens_706posts.xml',
#  '11-09-20s_706posts.xml',
#  '11-09-40s_706posts.xml',
#  '11-09-adults_706posts.xml',
#  '11-09-teens_706posts.xml']

# %%
for x in nps_chat.readme():
    print(x)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-9dde306d7f3c> in <module>
# ----> 1 for x in nps_chat.readme():
#       2     print(x)
#
# ~/anaconda3/envs/chill/lib/python3.8/site-packages/nltk/corpus/reader/api.py in readme(self)
#     131         Return the contents of the corpus README file, if it exists.
#     132         """
# --> 133         return self.open("README").read()
#     134
#     135     def license(self):
#
# ~/anaconda3/envs/chill/lib/python3.8/site-packages/nltk/corpus/reader/api.py in open(self, file)
#     206         """
#     207         encoding = self.encoding(file)
# --> 208         stream = self._root.join(file).open(encoding)
#     209         return stream
#     210
#
# ~/anaconda3/envs/chill/lib/python3.8/site-packages/nltk/data.py in join(self, fileid)
#     335     def join(self, fileid):
# ...

# %%
cr = nps_chat.posts('11-06-adults_706posts.xml')

# %%
cr[5]
# Out:
# ['Welcome',
#  'to',
#  '#talkcity_adults',
#  ',',
#  'JTo',
#  'get',
#  'your',
#  'own',
#  'game',
#  'bot',
#  'for',
#  'your',
#  'chat',
#  'room',
#  'please',
#  'contact',
#  'Dawnstar',
#  'Visit',
#  'http://www.shadowbots.com']

# %%
for fid in nps_chat.fileids()[:10]:
    print(fid, nps_chat.raw(fid))
# Out:
# 10-19-20s_706posts.xml <!-- edited with XMLSpy v2007 sp1 (http://www.altova.com) by Eric Forsyth (Naval Postgraduate School) -->
# <Session xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="postClassPOSTagset.xsd">
# 	<Posts>
# 		<Post class="Statement" user="10-19-20sUser7">now im left with this gay name<terminals>
# 				<t pos="RB" word="now"/>
# 				<t pos="PRP" word="im"/>
# 				<t pos="VBD" word="left"/>
# 				<t pos="IN" word="with"/>
# 				<t pos="DT" word="this"/>
# 				<t pos="JJ" word="gay"/>
# 				<t pos="NN" word="name"/>
# 			</terminals>
# 		</Post>
# 		<Post class="Emotion" user="10-19-20sUser7">:P<terminals>
# 				<t pos="UH" word=":P"/>
# 			</terminals>
# 		</Post>
# 		<Post class="System" user="10-19-20sUser76">PART<terminals>
# 				<t pos="VB" word="PART"/>
# 			</terminals>
# 		</Post>
# 		<Post class="Greet" user="10-19-20sUser59">hey everyone  <terminals>
# 				<t pos="UH" word="hey"/>
# 				<t pos="NN" word="everyone"/>
# ...
